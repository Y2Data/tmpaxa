# %%
import pandas as pd

# %%
df = pd.read_csv('./example_data_2019_v1.csv')

# %%
def clean_df(df):
    df = df.drop(columns=['Category'])
    df.Action_time = pd.DataFrame.astype(df.Action_time, "datetime64[ns]")
    return df

# %%
df = clean_df(df)
df
# Out:
#                     Action_time           User_ID  \
# 0    2019-07-22 09:00:28.572171  10x2217145yz7380
# 1    2019-07-22 09:00:31.247942  10x2217145yz7380
# 2    2019-07-22 09:00:31.547277  10x2217145yz7380
# 3    2019-07-22 09:00:40.279945  10x2217145yz7380
# 4    2019-07-22 09:00:40.608830  10x2217145yz7380
# ...                         ...               ...
# 9434 2019-07-22 09:15:43.677232   10x221994yz7381
# 9435 2019-07-22 09:21:34.956551   10x221994yz7381
# 9436 2019-07-22 09:24:39.028309   10x221994yz7381
# 9437 2019-07-22 09:34:31.903480   10x221994yz7381
# 9438 2019-07-22 09:07:50.211207   10x221994yz7381
#
#                                                     URL
# 0        POST https://genyplc.com:490/task/chk HTTP/1.1
# 1     GET https://genyplc.com:490/task/orderdetail/1...
# 2     GET https://genyplc.com:490/task/saif/zandag?p...
# 3     GET https://genyplc.com:490/papi/v1/specialsea...
# 4     GET https://genyplc.com:490/task/saif/zandag?p...
# ...

# %%
allUsers = df.User_ID.unique().tolist()
allDataFrames = [df[df.User_ID == user] for user in allUsers]
tmp = allDataFrames[0]

# %%
tmp['more_than_5m59s'] = tmp['Action_time'].diff() > pd.Timedelta(seconds=359)
tmp[tmp.more_than_5m59s == True]
# Out:
# /var/folders/hx/q4f_r6rs13l1jtb0sx0f_78h0000gp/T/ipykernel_58592/4036680322.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['more_than_5m59s'] = tmp['Action_time'].diff() > pd.Timedelta(seconds=359)
#                    Action_time           User_ID  \
# 28  2019-07-22 09:10:32.974671  10x2217145yz7380
# 165 2019-07-22 09:20:29.126020  10x2217145yz7380
# 327 2019-07-22 09:30:28.609421  10x2217145yz7380
# 519 2019-07-22 09:40:28.383668  10x2217145yz7380
# 677 2019-07-22 09:50:38.854742  10x2217145yz7380
# 850 2019-07-22 09:59:27.894580  10x2217145yz7380
#
#                                                    URL  more_than_5m59s
# 28   GET https://genyplc.com:490/task/orderdetail/1...             True
# ...
